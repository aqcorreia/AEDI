# %% [markdown]
# # Análise Estatística de Dados e Informações
# **PPCA/UNB**
#
# ---
#
# **Prova - Questão 03**
# **Professor**: João Gabriel de Moraes Sousa
# **Aluna**: Andreia Queiroz Correia Dummar
# **Matrícula**: 241134680
# **Data da Entrega**: 09/02/2025
# **Github**: https://github.com/aqcorreia/AEDI/tree/main/Prova
#
# ---
#
# **Aplicação**: ANOVA (Análise de Variância)
#
# **Dados**: Vendas de Varejo Online (https://www.kaggle.com/datasets/mathchi/online-retail-ii-data-set-from-ml-repository?select=online_retail_II.xlsx)

# %% [markdown]
# ---
#
# O dataset **Online Retail** contém informações sobre transações de uma loja de comércio eletrônico sediada no Reino Unido. Ele registra detalhes das compras feitas por clientes entre **2009 e 2010**.
#
# Contém as seguintes colunas:
#
# | **Coluna**        | **Descrição** |
# |------------------|--------------|
# | `Invoice`       | Número da fatura da transação. |
# | `StockCode`     | Código único do produto. |
# | `Description`   | Nome ou descrição do produto. |
# | `Quantity`      | Quantidade de itens comprados na transação. |
# | `InvoiceDate`   | Data e hora da compra. |
# | `Price`         | Preço unitário do produto. |
# | `Customer ID`   | Identificador do cliente. |
# | `Country`       | País do cliente. |
#
# ---

# %% [markdown]
# ## 1) Bibliotecas

# %%
# Bibliotecas para manipulação de dados
import pandas as pd
import numpy as np

# Bibliotecas para estatísticas
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import normaltest

# Bibliotecas para visualização
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2) Funções

# %%
def verificar_valores_faltantes(df):
    """
    Função para verificar valores faltantes em um DataFrame.

    Parâmetros:
        df (pd.DataFrame): O DataFrame a ser analisado.

    Retorno:
        pd.DataFrame: DataFrame com as colunas, a quantidade de valores faltantes e o percentual correspondente.
    """
    # Contar valores faltantes por coluna
    valores_faltantes = df.isnull().sum()
    
    # Filtrar apenas colunas com valores faltantes (ignorar valores zero)
    valores_faltantes = valores_faltantes[valores_faltantes > 0]
    
    # Calcular o percentual de valores faltantes
    percentual_faltante = (valores_faltantes / len(df)) * 100
    
    # Criar DataFrame com as informações
    resultado = pd.DataFrame({
        'Coluna': valores_faltantes.index,
        'Valores Faltantes': valores_faltantes.values,
        'Percentual Faltante (%)': percentual_faltante.values
    })
    
    # Ordenar pelo número de valores faltantes
    resultado = resultado.sort_values(by='Valores Faltantes', ascending=False).reset_index(drop=True)
    
    return resultado

# %%
def plot_boxplot(df, coluna_categorica, coluna_numerica):
    """
    Gera um boxplot para visualizar a relação entre uma variável categórica e uma variável numérica.

    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os dados.
        coluna_categorica (str): Nome da coluna categórica para o eixo X.
        coluna_numerica (str): Nome da coluna numérica para o eixo Y.
    """
    plt.figure(figsize=(20, 6))  # Ajusta o tamanho para melhor visualização

    # Correção do FutureWarning: Definir explicitamente 'hue' e desativar a legenda
    sns.boxplot(x=coluna_categorica, y=coluna_numerica, hue=coluna_categorica, data=df, palette='coolwarm', legend=False)

    plt.xticks(rotation=90)  # Rotaciona os rótulos para evitar sobreposição
    plt.title(f'{coluna_numerica} vs. {coluna_categorica}')
    plt.xlabel(coluna_categorica)
    plt.ylabel(coluna_numerica)

    plt.show()

# %%
def plot_media_confidence(df, coluna_categorica, coluna_numerica):
    """
    Gera um gráfico de médias por categoria com intervalo de confiança de 95%.
    
    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os dados.
        coluna_categorica (str): Nome da coluna categórica (eixo X).
        coluna_numerica (str): Nome da coluna numérica (eixo Y).
    """
    plt.figure(figsize=(15, 6))

    # Correção do FutureWarning: Substituindo ci pelo novo errorbar
    sns.pointplot(x=coluna_categorica, y=coluna_numerica, data=df, errorbar=('ci', 95), capsize=0.2, color='b')

    plt.xticks(rotation=90)
    plt.title(f'Média de {coluna_numerica} por {coluna_categorica} (com intervalo de confiança 95%)')
    plt.xlabel(coluna_categorica)
    plt.ylabel(f'Média de {coluna_numerica}')

    plt.show()

# %%
def plot_violinplot(df, coluna_categorica, coluna_numerica):
    """
    Gera um Violin Plot para visualizar a distribuição de uma variável numérica por categorias.

    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os dados.
        coluna_categorica (str): Nome da coluna categórica (eixo X).
        coluna_numerica (str): Nome da coluna numérica (eixo Y).
    """
    plt.figure(figsize=(15, 6))

    # Correção do FutureWarning: Adicionando hue e desativando legenda
    sns.violinplot(x=coluna_categorica, y=coluna_numerica, hue=coluna_categorica, data=df, palette='coolwarm', legend=False)

    plt.xticks(rotation=90)
    plt.title(f'Distribuição de {coluna_numerica} por {coluna_categorica}')
    plt.xlabel(coluna_categorica)
    plt.ylabel(coluna_numerica)

    plt.show()

# %%
def validar_pressupostos_anova(quantity_groups, price_groups, filtered_df):
    # Calcular resíduos para Quantity
    residuals_quantity = []
    for country in filtered_df['Country'].unique():
        country_data = filtered_df[filtered_df['Country'] == country]['Quantity'].dropna()
        mean_quantity = country_data.mean()
        residuals_quantity.extend(country_data - mean_quantity)
    residuals_quantity = np.array(residuals_quantity)

    # Calcular resíduos para Price
    residuals_price = []
    for country in filtered_df['Country'].unique():
        country_data = filtered_df[filtered_df['Country'] == country]['Price'].dropna()
        mean_price = country_data.mean()
        residuals_price.extend(country_data - mean_price)
    residuals_price = np.array(residuals_price)

    # 1. Teste de Normalidade (D’Agostino-Pearson)
    _, p_value_quantity = stats.normaltest(residuals_quantity)
    _, p_value_price = stats.normaltest(residuals_price)

    print("\nTeste de Normalidade (D’Agostino-Pearson):")
    print(f"Quantity: p-valor = {p_value_quantity:.4e}")
    print(f"Price: p-valor = {p_value_price:.4e}")

    # 2. Teste de Homocedasticidade (Levene)
    levene_quantity = stats.levene(*quantity_groups)
    levene_price = stats.levene(*price_groups)

    print("\nTeste de Homocedasticidade (Levene):")
    print(f"Quantity: W = {levene_quantity.statistic:.4f}, p-valor = {levene_quantity.pvalue:.4e}")
    print(f"Price: W = {levene_price.statistic:.4f}, p-valor = {levene_price.pvalue:.4e}")

    # 3. Visualização dos resíduos
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sm.qqplot(residuals_quantity, line='s', ax=plt.gca())
    plt.title("QQ-Plot - Resíduos Quantity")

    plt.subplot(1, 2, 2)
    sm.qqplot(residuals_price, line='s', ax=plt.gca())
    plt.title("QQ-Plot - Resíduos Price")

    plt.show()

# %%
def ajustar_modelo(filtered_df):
    # 1. Transformação logarítmica corrigida para evitar log de zero ou negativos
    filtered_df['Log_Quantity'] = np.log1p(filtered_df['Quantity'].clip(lower=0.01))
    filtered_df['Log_Price'] = np.log1p(filtered_df['Price'].clip(lower=0.01))
    
    # 2. Teste de Kruskal-Wallis (alternativa não paramétrica à ANOVA)
    kw_quantity = stats.kruskal(*[filtered_df[filtered_df['Country'] == country]['Quantity'].dropna() for country in filtered_df['Country'].unique()])
    kw_price = stats.kruskal(*[filtered_df[filtered_df['Country'] == country]['Price'].dropna() for country in filtered_df['Country'].unique()])
    
    print("\nTeste de Kruskal-Wallis:")
    print(f"Quantity: H = {kw_quantity.statistic:.4f}, p-valor = {kw_quantity.pvalue:.4e}")
    print(f"Price: H = {kw_price.statistic:.4f}, p-valor = {kw_price.pvalue:.4e}")
    
    # 3. Ajustar um modelo de regressão robusta (GLM)
    model_quantity = smf.glm("Log_Quantity ~ Country", data=filtered_df, family=sm.families.Gaussian()).fit()
    model_price = smf.glm("Log_Price ~ Country", data=filtered_df, family=sm.families.Gaussian()).fit()
    
    print("\nModelo de Regressão - Log(Quantity):")
    print(model_quantity.summary())
    
    print("\nModelo de Regressão - Log(Price):")
    print(model_price.summary())

# %% [markdown]
# ## 3) Leitura do arquivo

# %%
# # Diretório do arquivo
# diretorio = './dados'

# # Lendo o arquivo Excel corretamente
# online_retail_data = pd.read_excel(f'{diretorio}/online_retail_II.xlsx')

# # Exibindo o tamanho do DataFrame
# online_retail_data.shape

# %%
# online_retail_data.head()

# %%
# online_retail_data.dtypes

# %%
# # Para melhorar a performance, o arquivo será salvo no formato parquet

# # Converter colunas problemáticas para string
# online_retail_data["Invoice"] = online_retail_data["Invoice"].astype(str)
# online_retail_data["StockCode"] = online_retail_data["StockCode"].astype(str)
# online_retail_data["Description"] = online_retail_data["Description"].astype(str)

# # Caminho para salvar
# caminho_parquet = "./dados/online_retail_data.parquet"

# # Salvando o DataFrame em formato Parquet
# online_retail_data.to_parquet(caminho_parquet, index=False)

# %%
# Caminho do arquivo Parquet
caminho_parquet = "./dados/online_retail_data.parquet"

# Ler o arquivo Parquet
online_retail_data = pd.read_parquet(caminho_parquet)

# %% [markdown]
# ## 4) Análise descritiva

# %% [markdown]
# ### 4.1) Análise geral

# %%
online_retail_data.shape
# Out:
# (525461, 8)

# %%
online_retail_data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
online_retail_data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
online_retail_data.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
online_retail_data.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
# Lista países
df_paises = pd.DataFrame({"País": online_retail_data["Country"].unique()})

df_paises.head(100)
# Out:
#                     País
# 0         United Kingdom
# 1                 France
# 2                    USA
# 3                Belgium
# 4              Australia
# 5                   EIRE
# 6                Germany
# 7               Portugal
# 8                  Japan
# 9                Denmark
# 10               Nigeria
# 11           Netherlands
# 12                Poland
# 13                 Spain
# 14       Channel Islands
# 15                 Italy
# 16                Cyprus
# 17                Greece
# 18                Norway
# 19               Austria
# 20                Sweden
# 21  United Arab Emirates
# 22               Finland
# 23           Switzerland
# 24           Unspecified
# 25                 Malta
# 26               Bahrain
# 27                   RSA
# 28               Bermuda
# 29             Hong Kong
# 30             Singapore
# 31              Thailand
# 32                Israel
# 33             Lithuania
# 34           West Indies
# 35               Lebanon
# ...

# %% [markdown]
# ### 4.2) Verificar valores faltantes

# %%
result = verificar_valores_faltantes(online_retail_data)

if result.empty:
    print("Não há valores faltantes")
else:
    print(result.head(100))
# Out:
#         Coluna  Valores Faltantes  Percentual Faltante (%)
# 0  Customer ID             107927                20.539488

# %% [markdown]
# ### 4.3) Análise das variáveis de interesse

# %% [markdown]
# #### 4.3.1) Análise `Quantity`

# %%
coluna_numerica = 'Quantity'

plot_boxplot(online_retail_data, 'Country', coluna_numerica)

plot_media_confidence(online_retail_data, 'Country', coluna_numerica)

plot_violinplot(online_retail_data, 'Country', coluna_numerica)

# %% [markdown]
# ---
#
# A análise dos três gráficos revela possíveis violações das suposições da ANOVA para a variável **Quantity**. O **boxplot** evidencia alta dispersão e presença de outliers extremos em alguns países, como **United Kingdom, Denmark e Japan**, sugerindo possível violação da homogeneidade das variâncias. O **gráfico de médias com intervalo de confiança** indica diferenças significativas entre os países, mas também mostra intervalos de confiança muito amplos para alguns grupos, o que pode indicar alta variabilidade dentro das categorias. Já o **violin plot** confirma distribuições assimétricas e caudas longas para algumas categorias, apontando para possíveis desvios da normalidade.
#
# ---

# %% [markdown]
# #### 4.3.2) Análise `Price`

# %%
coluna_numerica = 'Price'

plot_boxplot(online_retail_data, 'Country', coluna_numerica)

plot_media_confidence(online_retail_data, 'Country', coluna_numerica)

plot_violinplot(online_retail_data, 'Country', coluna_numerica)

# %% [markdown]
# ---
#
# A análise dos três gráficos sugere possíveis violações das suposições da ANOVA para a variável **Price**. O **boxplot** evidencia grande dispersão e presença de outliers extremos, especialmente em países como **United Kingdom, Norway e Hong Kong**, indicando possível violação da homogeneidade das variâncias. O **gráfico de médias com intervalo de confiança** revela que alguns países apresentam médias significativamente diferentes, mas com intervalos de confiança muito amplos, o que pode indicar alta variabilidade dentro dos grupos. Já o **violin plot** confirma distribuições assimétricas e caudas longas para algumas categorias, sugerindo que a suposição de normalidade pode estar comprometida.
#
# ---

# %% [markdown]
# ## 5) Análise ANOVA

# %% [markdown]
# ### 5.1) Análise ANOVA

# %%
# Filtrando para manter apenas os países que aparecem mais de uma vez, pois a ANOVA precisa de pelo menos dois valores por grupo para funcionar.
valid_countries = online_retail_data['Country'].value_counts()
valid_countries = valid_countries[valid_countries > 1].index
filtered_df = online_retail_data[online_retail_data['Country'].isin(valid_countries)]

# Separar os dados por país para Quantity e Price
quantity_groups = [filtered_df[filtered_df['Country'] == country]['Quantity'].dropna() for country in filtered_df['Country'].unique()]
price_groups = [filtered_df[filtered_df['Country'] == country]['Price'].dropna() for country in filtered_df['Country'].unique()]

# Realizar ANOVA para Quantity e Price
anova_quantity = stats.f_oneway(*quantity_groups)
anova_price = stats.f_oneway(*price_groups)

# Exibir resultados
print("ANOVA para Quantity:")
print(f"F = {anova_quantity.statistic:.4f}, p-valor = {anova_quantity.pvalue:.4e}")
print("\nANOVA para Price:")
print(f"F = {anova_price.statistic:.4f}, p-valor = {anova_price.pvalue:.4e}")
# Out:
# ANOVA para Quantity:
# F = 292.1790, p-valor = 0.0000e+00
#
# ANOVA para Price:
# F = 5.0687, p-valor = 4.2828e-23

# %% [markdown]
# ---
#
# A análise de variância (ANOVA) revelou diferenças estatisticamente significativas tanto para a quantidade vendida (`Quantity`) quanto para o preço (`Price`) entre os países.
#
# - **ANOVA para Quantity**:
#   - **F = 292.1790**, **p-valor ≈ 0**
#   - Forte variação entre os países na quantidade média vendida.
#
# - **ANOVA para Price**:
#   - **F = 5.0687**, **p-valor = 4.2828e-23**
#   - Diferenças significativas nos preços médios, mas com menor variação em relação à quantidade.
#
# ---

# %% [markdown]
# ### 5.2) Verificação dos pressupostos ANOVA

# %% [markdown]
# ---
# #### 1. Normalidade dos Resíduos → **Teste de Shapiro-Wilk**
# - Avalia se os resíduos seguem uma distribuição normal.
# - Se o **p-valor > 0.05**, assumimos que os resíduos são normalmente distribuídos.
#
# #### 2. Homocedasticidade (Igualdade de Variâncias) → **Teste de Levene**
# - Verifica se as variâncias dos grupos são aproximadamente iguais.
# - Se o **p-valor > 0.05**, assumimos que as variâncias são homogêneas.
#
# #### 3. Independência dos Dados
# - A ANOVA assume que as observações são **independentes entre si**.
# - Esse pressuposto depende do processo de coleta dos dados e deve ser garantido pelo pesquisador.
#
# ---

# %%
validar_pressupostos_anova(quantity_groups, price_groups, filtered_df)
# Out:
# Teste de Normalidade (D’Agostino-Pearson):
# Quantity: p-valor = 0.0000e+00
# Price: p-valor = 0.0000e+00
#
# Teste de Homocedasticidade (Levene):
# Quantity: W = 299.4525, p-valor = 0.0000e+00
# Price: W = 5.0214, p-valor = 9.0746e-23

# %% [markdown]
# ---
#
# **1. Teste de Normalidade (D’Agostino-Pearson)**
# - Como a amostra analisada possui 525.461 observações, o **teste de Shapiro-Wilk** não se mostrou confiável uma vez que sua utilização é recomendada para amostras de até 5.000 observações, portanto, utilizou-se o **teste de normalidade D’Agostino-Pearson**. Ao combinar assimetria (skewness) e curtose (kurtosis) para verificar desvios da normalidade, se torna mais adequado para grandes amostras.
# - Quantity: p-valor = 0.0000
# - Price: p-valor = 0.0000
#
# Os p-valores são muito pequenos (menores que 0.05), o que indica que os resíduos não seguem uma distribuição normal.
#
# **2. Teste de Homocedasticidade (Levene)**
# - Quantity: W = 299.4525, p-valor = 0.0000
# - Price: W = 5.0214, p-valor = 9.0746e-23
#
# Os p-valores muito pequenos sugerem que as variâncias não são homogêneas entre os grupos, indicando uma violação do pressuposto de homocedasticidade.
#
# **3. QQ-Plots dos Resíduos**
# Os gráficos **QQ-Plot** ajudam a visualizar a normalidade dos resíduos:
#
# - Quantity: Os pontos se afastam significativamente da linha teórica, especialmente nas extremidades.
# - Price: Os pontos também mostram desvios notáveis em relação à normalidade.
#
# ---

# %% [markdown]
# ### 5.3) Ajuste do modelo

# %%
ajustar_modelo(filtered_df)
# Out:
# Teste de Kruskal-Wallis:
# Quantity: H = 21615.2682, p-valor = 0.0000e+00
# Price: H = 1454.1417, p-valor = 5.5543e-280
#
# Modelo de Regressão - Log(Quantity):
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           Log_Quantity   No. Observations:               525461
# Model:                            GLM   Df Residuals:                   525421
# Model Family:                Gaussian   Df Model:                           39
# Link Function:               Identity   Scale:                          1.0048
# Method:                          IRLS   Log-Likelihood:            -7.4682e+05
# Date:                Sun, 09 Feb 2025   Deviance:                   5.2792e+05
# Time:                        18:46:08   Pearson chi2:                 5.28e+05
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.04623
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ---
#
# **1. Teste de Kruskal-Wallis**
# - **Quantity: H = 21615.2682, p-valor = 0.0000**
# - **Price: H = 1454.1417, p-valor = 5.5543e-280**
#
# Os resultados indicam que há **diferenças estatisticamente significativas** entre os países tanto para `Quantity` quanto para `Price`. Isso confirma que os países possuem distribuições de quantidade e preço diferentes.
#
# **2. Modelo de Regressão - Log(Quantity)**
# - Diversos países apresentam coeficientes **estatisticamente significativos** (p-valor < 0.05), sugerindo variação na quantidade média vendida entre países.
# - Alguns países possuem coeficientes **negativos**, indicando que a quantidade média vendida é menor em comparação com a referência (`Intercept`).
# - O **pseudo R² = 0.04623** indica que o modelo explica apenas **4.6% da variação** em `Log_Quantity`, sugerindo que outros fatores influenciam as quantidades vendidas.
#
# **3. Modelo de Regressão - Log(Price)**
# - Para `Log_Price`, alguns países apresentam coeficientes **estatisticamente significativos**, enquanto outros não.
# - O **pseudo R² = 0.001985**, ou seja, o modelo **explica menos de 0.2% da variação** no preço, indicando que `Country` tem **pouca influência** na variação de preço.
#
# ---
#
# **Resumo**
# - As diferenças entre os países são **estatisticamente significativas** para `Quantity` e `Price`, conforme o **teste de Kruskal-Wallis**.
# - O modelo de regressão para `Log_Quantity` sugere que **alguns países têm quantidades médias significativamente diferentes**.
# - O modelo de regressão para `Log_Price` sugere que o país **tem pouca influência na variação de preços**.
# - O **baixo R² nos modelos** indica que **outros fatores além do país afetam as vendas**.
#
# ---

# %% [markdown]
# ## 6) Tomada de decisão

# %% [markdown]
# ---
#
# **Decisões Estratégicas Baseadas nos Resultados**
#
# **1. Personalização de Preços por Mercado**
#
# 🔹 **Precificação dinâmica baseada na demanda** → A empresa pode **ajustar os preços em mercados onde os consumidores estão dispostos a pagar mais** e oferecer **descontos onde a sensibilidade ao preço for alta**.
# 🔹 **Modelos preditivos mais robustos** → Explorar **modelos de Machine Learning** para entender **outros fatores que impactam o preço**.
#
# **2 Estratégia de Estoque e Distribuição**
#
# 🔹 **Realocar estoques para países com maior demanda** → Como Dinamarca e Holanda apresentaram alto impacto positivo, esses mercados devem receber **prioridade na alocação de produtos**.
# 🔹 **Reduzir riscos em mercados com baixa demanda** → Em países como Brasil e Nigéria, pode-se **testar campanhas promocionais** antes de comprometer grandes estoques.
#
# **3 Estratégia de Marketing Regional**
#
# 🔹 **Promoções agressivas em mercados com vendas baixas** → Campanhas específicas podem ser direcionadas para **estímulo da demanda em mercados como Brasil e Líbano**.
# 🔹 **Destaque de diferenciais em mercados premium** → Para mercados onde os clientes pagam mais, é possível **reforçar o posicionamento premium do produto**.
#
# **4 Expansão e Investimento**
#
# 🔹 **Expandir para países com maior potencial de vendas** → Focar investimentos em **países onde a demanda e os preços são mais favoráveis**.
# 🔹 **Evitar investimentos excessivos em mercados de baixa performance**, a menos que **mudanças estratégicas sejam aplicadas** para melhorar a aceitação do produto.
#
#
# **Conclusão Final**
# - Os resultados indicam que a estratégia de vendas deve ser adaptada para diferentes mercados, considerando a variação de demanda e sensibilidade ao preço.
# - O modelo de `Log(Quantity)` sugere que fatores locais impactam fortemente as vendas, e ajustes estratégicos devem ser feitos por país.
# - O modelo de `Log(Price)` mostra que a precificação precisa ser mais dinâmica e considerar fatores além da localização.
#
# ---
